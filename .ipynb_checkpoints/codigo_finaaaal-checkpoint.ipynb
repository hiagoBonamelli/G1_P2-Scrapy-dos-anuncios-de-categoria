# %% [markdown]
# # Importar bibliotecas:

# %%
import pandas as pd
import os
import webbrowser
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import threading
import logging
import time

# %% [markdown]
# ### Encontrar diretorio:

# %%
path = (r"./bases/")
print(path)#Mostrar
# Out:
# ./bases/

# %%
file = os.listdir(path)#Mostrar o que tem dentro da pasta dos 5 CSV
print(file)#Mostrar
# Out:
# ['10-11_pagina_1.csv', '100-101_pagina_1.csv', '100-101_pagina_10.csv', '100-101_pagina_11.csv', '100-101_pagina_12.csv', '100-101_pagina_13.csv', '100-101_pagina_14.csv', '100-101_pagina_15.csv', '100-101_pagina_16.csv', '100-101_pagina_17.csv', '100-101_pagina_18.csv', '100-101_pagina_19.csv', '100-101_pagina_2.csv', '100-101_pagina_20.csv', '100-101_pagina_21.csv', '100-101_pagina_22.csv', '100-101_pagina_23.csv', '100-101_pagina_24.csv', '100-101_pagina_25.csv', '100-101_pagina_26.csv', '100-101_pagina_27.csv', '100-101_pagina_28.csv', '100-101_pagina_29.csv', '100-101_pagina_3.csv', '100-101_pagina_30.csv', '100-101_pagina_31.csv', '100-101_pagina_32.csv', '100-101_pagina_33.csv', '100-101_pagina_34.csv', '100-101_pagina_35.csv', '100-101_pagina_36.csv', '100-101_pagina_37.csv', '100-101_pagina_38.csv', '100-101_pagina_39.csv', '100-101_pagina_4.csv', '100-101_pagina_40.csv', '100-101_pagina_5.csv', '100-101_pagina_6.csv', '100-101_pagina_7.csv', '100-101_pagina_8.csv', '100-101_pagina_9.csv', '1000-1001_pagina_1.csv', '1000-1100_pagina_1.csv', '1000-1100_pagina_10.csv', '1000-1100_pagina_11.csv', '1000-1100_pagina_12.csv', '1000-1100_pagina_13.csv', '1000-1100_pagina_14.csv', '1000-1100_pagina_15.csv', '1000-1100_pagina_16.csv', '1000-1100_pagina_17.csv', '1000-1100_pagina_18.csv', '1000-1100_pagina_19.csv', '1000-1100_pagina_2.csv', '1000-1100_pagina_20.csv', '1000-1100_pagina_21.csv', '1000-1100_pagina_22.csv', '1000-1100_pagina_23.csv', '1000-1100_pagina_24.csv', '1000-1100_pagina_25.csv', '1000-1100_pagina_26.csv', '1000-1100_pagina_27.csv', '1000-1100_pagina_28.csv', '1000-1100_pagina_29.csv', '1000-1100_pagina_3.csv', '1000-1100_pagina_30.csv', '1000-1100_pagina_31.csv', '1000-1100_pagina_32.csv', '1000-1100_pagina_33.csv', '1000-1100_pagina_34.csv', '1000-1100_pagina_35.csv', '1000-1100_pagina_36.csv', '1000-1100_pagina_37.csv', '1000-1100_pagina_38.csv', '1000-1100_pagina_39.csv', '1000-1100_pagina_4.csv', '1000-1100_pagina_5.csv', '1000-1100_pagina_6.csv', '1000-1100_pagina_7.csv', '1000-1100_pagina_8.csv', '1000-1100_pagina_9.csv', '1001-1002_pagina_1.csv', '1002-1003_pagina_1.csv', '1003-1004_pagina_1.csv', '1004-1005_pagina_1.csv', '1005-1006_pagina_1.csv', '1006-1007_pagina_1.csv', '1007-1008_pagina_1.csv', '1008-1009_pagina_1.csv', '1008-1009_pagina_2.csv', '1009-1010_pagina_1.csv', '101-102_pagina_1.csv', '101-102_pagina_10.csv', '101-102_pagina_11.csv', '101-102_pagina_12.csv', '101-102_pagina_13.csv', '101-102_pagina_14.csv', '101-102_pagina_15.csv', '101-102_pagina_16.csv', '101-102_pagina_17.csv', '101-102_pagina_18.csv', '101-102_pagina_19.csv', '101-102_pagina_2.csv', '101-102_pagina_20.csv', '101-102_pagina_21.csv', '101-102_pagina_22.csv', '101-102_pagina_23.csv', '101-102_pagina_24.csv', '101-102_pagina_25.csv', '101-102_pagina_26.csv', '101-102_pagina_27.csv', '101-102_pagina_28.csv', '101-102_pagina_29.csv', '101-102_pagina_3.csv', '101-102_pagina_30.csv', '101-102_pagina_31.csv', '101-102_pagina_32.csv', '101-102_pagina_33.csv', '101-102_pagina_34.csv', '101-102_pagina_35.csv', '101-102_pagina_36.csv', '101-102_pagina_37.csv', '101-102_pagina_38.csv', '101-102_pagina_39.csv', '101-102_pagina_4.csv', '101-102_pagina_40.csv', '101-102_pagina_5.csv', '101-102_pagina_6.csv', '101-102_pagina_7.csv', '101-102_pagina_8.csv', '101-102_pagina_9.csv', '1010-1011_pagina_1.csv', '1011-1012_pagina_1.csv', '1012-1013_pagina_1.csv', '1013-1014_pagina_1.csv', '1014-1015_pagina_1.csv', '1015-1016_pagina_1.csv', '1016-1017_pagina_1.csv', '1017-1018_pagina_1.csv', '1018-1019_pagina_1.csv', '1019-1020_pagina_1.csv', '102-103_pagina_1.csv', '102-103_pagina_10.csv', '102-103_pagina_11.csv', '102-103_pagina_12.csv', '102-103_pagina_13.csv', '102-103_pagina_14.csv', '102-103_pagina_15.csv', '102-103_pagina_16.csv', '102-103_pagina_17.csv', '102-103_pagina_18.csv', '102-103_pagina_19.csv', '102-103_pagina_2.csv', '102-103_pagina_20.csv', '102-103_pagina_21.csv', '102-103_pagina_22.csv', '102-103_pagina_23.csv', '102-10 ...

# %%
driver = webdriver.Firefox()

# %%
driver.get('https://produto.mercadolivre.com.br/MLB-826163456-vela-aquecedora-fiat-ducato-peugeot-boxer-citroen-jumper-_JM#position=48&search_layout=stack&type=item&tracking_id=cbaeb09e-02ae-4591-87a1-33167e5c800d')

# %% [markdown]
# #### Teste de xpath:

# %%
preco = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[1]/div/div[1]/div/div[2]/div/div[1]/span/span[2]').text
preco.replace('\n', '')
# Out:
# 'R$20'

# %%
preco = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[2]/div/div[1]/span/span[2]').text
xd.replace('\n', '')

# %% [markdown]
# ### Codigo Final:

# %%
aux_erro = 0
driver = webdriver.Firefox()

# %%
for files in file:
    #print(files)
    print(f'\033[31m'+str(files)+'\033[0;0m')
    df = pd.read_csv(path + files)      
    guarda_info = []

    for index, row in df.iterrows():
        #print(index)
        time.sleep(1.8)
        driver.get(row['urls'])
        
        try:
            try:
                try:
                    titulo = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[1]/div/div[1]/div/div[1]/div/div[2]/h1').text
                    #print('Titulo:',titulo)
                except:
                    titulo = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[1]/div[1]/div/div[1]/div/div[2]/h1').text
                    #print('Titulo:',titulo)
            except:
                titulo = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[1]/div[1]/div/div[1]/div/div[2]/h1').text
                #print('Titulo:',titulo)
        except:
            titulo = 'Não tem titulo'
            #print(f'\033[31m'+str(titulo)+'\033[0;0m')

        try:
            try:
                try:
                    preco = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[2]/div/div[1]/span/span[2]').text
                    preco.replace('\n', '')
                except:
                    preco = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[1]/div/div[1]/div/div[2]/div/div[1]/span/span[2]').text
                    preco.replace('\n', '')
            except:
                preco = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[1]/div[1]/div/div[2]/div/div[1]/span/span[2]').text
                preco.replace('\n', '')
        except:
            preco = 'não tem preço'
            #print(f'\033[31m'+str(preco)+'\033[0;0m')

        try:    
            vendas_condicao = driver.find_element_by_xpath("/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[1]/div/div[1]/span").text
            condicao = vendas_condicao.split("|")[0].strip()
            try:
                vendas = int(vendas_condicao.split("|")[1].split()[0])
                #print('qntd vendida:',vendas)
            except:
                vendas = 0
        except:
            vendas = 'Não tem qntd de vendas'
            #print(f'\033[31m'+str(vendas)+'\033[0;0m')
        try:    
            try:    
                try:    
                    try:
                        marca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[1]/th').text
                        #print('MARCA:', marca)
                        if marca == "Marca":    
                            marca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[1]/td/span').text
                            #print('Marca:',marca1)
                        else:
                            sys.exit()
                    except:
                        marca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[1]/th').text
                        if marca == 'Marca':
                            marca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[1]/td/span').text
                            #print('Marca:',marca1)
                        else:
                            sys.exit()
                except:
                    marca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[1]/th').text
                    if marca == 'Marca':
                        marca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[1]/td/span').text
                        #print('Marca:',marca1)
                    else:
                        sys.exit()
            except:
                marca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[1]/th').text
                if marca == 'Marca':
                    marca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[1]/td/span').text
                    #print('Marca:',marca1)
                else:
                    sys.exit()
        except:
            marca1 = 'Não tem marca'
            #print(f'\033[31m'+str(marca1)+'\033[0;0m')

        try:    
            try:
                linha = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[2]/th').text
                #print('LINHA:',linha)
                if linha == "Linha":
                    linha1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[2]/td/span').text
                    #print('Linha:',linha1)
                else:
                    sys.exit()
            except:
                linha = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[2]/th').text
                #print('LINHA:',linha)
                if linha == "Linha":
                    linha1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[2]/td/span').text
                    #print('Linha:',linha1)
                else:
                    sys.exit()
        except:
            linha1 = 'Não tem linha'
            #print(f'\033[31m'+str(linha1)+'\033[0;0m')

        try:
            try:
                try:
                    try:
                        modelo = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[3]/th').text
                        #print('MODELO:',modelo)
                        if modelo == "Modelo":
                            modelo1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[3]/td/span').text
                            #print('Modelo:',modelo1)
                        else:
                            sys.exit()
                    except:
                        modelo = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[2]/th').text
                        #print('MODELO:',modelo)
                        if modelo == "Modelo":
                            modelo1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[2]/td').text
                            #print('Modelo:', modelo1)
                        else:
                            sys.exit()
                except:
                    modelo = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[2]/th').text
                    if modelo == "Modelo":
                        modelo1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[2]/td/span').text
                        #print('Modelo', modelo1)
                    else:
                        sys.exit()
            except:
                modelo = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[3]/th').text
                if modelo == "Modelo":
                    modelo1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[3]/td/span').text
                    #print('Modelo', modelo1)
                else:
                    sys.exit()
        except:
            modelo1 = 'Não tem modelo'
            #print(f'\033[31m'+str(modelo1)+'\033[0;0m')

        try:
            try:
                try:
                    try:
                        try:    
                            try:    
                                try:
                                    numero_peca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[4]/th').text
                                    if numero_peca == 'Número de peça':
                                        numero_peca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[4]/td/span').text
                                        #print('Numero de peça:', numero_peca1)
                                    else:
                                        sys.exit()
                                        #print('Numero de peça: diferente')
                                except:
                                    numero_peca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[3]/th').text
                                    if numero_peca == 'Número de peça':
                                        numero_peca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[3]/td/span').text
                                        #print('Numero de peça:', numero_peca1)
                                    else:
                                        sys.exit()
                            except:
                                numero_peca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[2]/th').text
                                if numero_peca == 'Número de peça':
                                    numero_peca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[2]/td/span').text
                                    #print('numero peça:',numero_peca1)
                                else:
                                    sys.exit()
                        except:
                            numero_peca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div/table/tbody/tr[2]/th').text
                            if numero_peca == 'Número de peça':
                                numero_peca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div/table/tbody/tr[2]/td/span').text
                                #print('numero peça:',numero_peca1)
                            else:
                                sys.exit()
                    except:
                        numero_peca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[3]/th').text
                        if numero_peca == "Número de peça":
                            numero_peca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[3]/td/span').text
                            #print('numero peça:', numero_peca1)
                        else:
                            sys.exit()
                except:
                    numero_peca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[4]/th').text
                    if numero_peca == "Número de peça":
                        numero_peca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[4]/td/span').text
                        #print('numero peça:', numero_peca1)
                    else:
                        sys.exit()
            except:
                numero_peca = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[2]/th').text
                if numero_peca == "Número de peça":
                    numero_peca1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[2]/td/span').text
                    #print('numero peça:', numero_peca1)
                else:
                    sys.exit()
        except:
            numero_peca1 = 'Não tem numero da peça'
            #print(f'\033[31m'+str(numero_peca1)+'\033[0;0m')

        try:
            try:
                try:    
                    try:    
                        try:
                            qntd_velas = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[5]/th').text
                            #print('Quantidade de velas:', qntd_velas)
                            if qntd_velas == 'Quantidade de velas':
                                qntd_velas1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[5]/td/span').text
                                #print('Quantidade de velas:',qntd_velas1)
                            else:
                                sys.exit()
                        except:
                            qntd_velas = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[4]/th').text
                            if qntd_velas == 'Quantidade de velas':
                                qntd_velas1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[3]/div/div[1]/table/tbody/tr[4]/td/span').text
                                #print('Quantidade de velas:', qntd_velas1)
                            else:
                                sys.exit()
                    except:
                        qntd_velas = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[3]/th').text
                        if qntd_velas == 'Quantidade de velas':
                            qntd_velas1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[3]/td/span').text
                            #print('Quantidade de velas:',qntd_velas1)
                        else:
                            sys.exit()
                except:
                    qntd_velas = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[4]/th').text
                    if qntd_velas == 'Quantidade de velas':
                        qntd_velas1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[4]/td/span').text
                        #print('Quantidade de velas:',qntd_velas1)
                    else:
                        sys.exit()
            except:
                qntd_velas = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[5]/th').text
                if qntd_velas == 'Quantidade de velas':
                    qntd_velas1 = driver.find_element_by_xpath('//*[@id="root-app"]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[5]/td/span').text
                    #print('Quantidade de velas:',qntd_velas1)
                else:
                    sys.exit()
        except:
            qntd_velas1 = 'Não tem quantidade de velas'
            #print(f'\033[31m'+str(qntd_velas1)+'\033[0;0m')



        dicionario = {"titulo":titulo,
              "preço":preco.replace('\n', ''),
              "condição":condicao,
              "qntd vendida":vendas,
                "marca":marca1,
             "linha": linha1,
             "modelo": modelo1,
             "numero_peça":numero_peca1,
             "qntd_velas":qntd_velas1,
            "url": row['urls'],
                                         }
        guarda_info.append(dicionario)

    df = pd.DataFrame(guarda_info)
    df.to_csv(f'./relatorios/relatorio{files}.csv')
    #df.to_excel(f'.relatorios_teste\relatorio{files}.xlsx')
# Out:
# 10-11_pagina_1.csv
# 100-101_pagina_1.csv
# 100-101_pagina_10.csv
# 100-101_pagina_11.csv
# 100-101_pagina_12.csv
# 100-101_pagina_13.csv
# 100-101_pagina_14.csv
# 100-101_pagina_15.csv
# 100-101_pagina_16.csv
# 100-101_pagina_17.csv
# 100-101_pagina_18.csv
# 100-101_pagina_19.csv
# 100-101_pagina_2.csv
# 100-101_pagina_20.csv
# 100-101_pagina_21.csv
# 100-101_pagina_22.csv
# 100-101_pagina_23.csv
# 100-101_pagina_24.csv
# 100-101_pagina_25.csv
# 100-101_pagina_26.csv
# 100-101_pagina_27.csv
# 100-101_pagina_28.csv
# 100-101_pagina_29.csv
# 100-101_pagina_3.csv
# 100-101_pagina_30.csv
# 100-101_pagina_31.csv
# 100-101_pagina_32.csv
# 100-101_pagina_33.csv
# 100-101_pagina_34.csv
# 100-101_pagina_35.csv
# 100-101_pagina_36.csv
# 100-101_pagina_37.csv
# 100-101_pagina_38.csv
# 100-101_pagina_39.csv
# 100-101_pagina_4.csv
# 100-101_pagina_40.csv
# 100-101_pagina_5.csv
# 100-101_pagina_6.csv
# 100-101_pagina_7.csv
# 100-101_pagina_8.csv
# 100-101_pagina_9.csv
# 1000-1001_pagina_1.csv
# 1000-1100_pagina_1.csv
# 1000-1100_pagina_10.csv
# 1000-1100_pagina_11.csv
# 1000-1100_pagina_12.csv
# 1000-1100_pagina_13.csv
# 1000-1100_pagina_14.csv
# 1000-1100_pagina_15.csv
# 1000-1100_pagina_16.csv
# 1000-1100_pagina_17.csv
# 1000-1100_pagina_18.csv
# 1000-1100_pagina_19.csv
# 1000-1100_pagina_2.csv
# 1000-1100_pagina_20.csv
# 1000-1100_pagina_21.csv
# 1000-1100_pagina_22.csv
# 1000-1100_pagina_23.csv
# 1000-1100_pagina_24.csv
# 1000-1100_pagina_25.csv
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-26-470b4d16e4be> in <module>
#       8         #print(index)
#       9         time.sleep(5.5)
# ---> 10         driver.get(row['urls'])
#      11
#      12         try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: TimedPromise timed out after 300000 ms

# %% [markdown]
# # Merge XLSX:

# %%
workbooks_path = r"C:\Users\kkaua\Data Science\Mercado Livre\Todos codigos\web-scraping-ml\juntar"
wbs = []

for file in os.listdir(workbooks_path):
    if not file.startswith("~$") and file.endswith(".xlsx"):
        wb = load_workbook(os.path.join(workbooks_path, file))
        wbs.append(wb)

# %%
final_wb = Workbook()
final_ws = final_wb.worksheets[0]
wb1 = wbs[0]
ws1 = wb1.worksheets[0]

# %%
for j in range(1, ws1.max_column+1):
    final_ws.cell(row=1, column=j).value = ws1.cell(row=1,   column=j).value

# %%
current_row = 2

for wb in wbs:
    for ws in wb.worksheets:
        mr = ws.max_row 
        mc = ws.max_column 

        for i in range (2, mr + 1): 
            for j in range (1, mc + 1): 
                current_cell = ws.cell(row = i, column = j) 
                final_ws.cell(row = current_row, column = j).value = current_cell.value

            current_row += 1

# %%
final_filename = "final_file.xlsx"
final_wb.save(os.path.join(workbooks_path, final_filename))
