# %% [markdown]
# # Como clickar e pegar informações ?

# %%
import pandas as pd
import os
import webbrowser
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import threading
import logging
import time

# %% [markdown]
# ### Ler 1 csv e testar

# %%
df = pd.read_csv(r'C:\Users\kkaua\Data Science\Mercado Livre\mercado_livre_2\identificar_colunas\5_bases\bases\21-22_pagina_17.csv')
df.head()
# Out:
#                                                 urls
# 0  https://click1.mercadolivre.com.br/mclics/clic...
# 1  https://produto.mercadolivre.com.br/MLB-145455...
# 2  https://produto.mercadolivre.com.br/MLB-145455...
# 3  https://produto.mercadolivre.com.br/MLB-145455...
# 4  https://produto.mercadolivre.com.br/MLB-145456...

# %% [markdown]
# ### Encontrar forma de clickar nas urls no data frame

# %%
df['urls']

# %% [markdown]
# ### Buscar as informações que preciso

# %%
titulo = '/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[1]/div/div[2]/h1'
quantidade_vendida = '/html/body/main/div/div[3]/div/div[1]/div/div[2]/div[1]/div/div/div[3]/ul/li[1]/strong'
preco = '/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[2]/div/div[1]/span/span[2]'
marca = '/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[1]'
linha = '/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[2]'
modelo = '/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[3]'
numero_preca = '/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[4]'
quantidade_velas = '/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[5]'

# %% [markdown]
# ### teste codigo para buscar

# %%
driver = webdriver.Firefox()
driver.get(df['urls'][48])
try:
    busca_linha = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[3]/td/span').text
    print(busca_linha)
except:
    print('Nao encontrei')
    busca_linha = ('Não encontrei linha')
#driver.close()

# %%
find = 'Novo'
if find == 'Novo':
    print('Caguei')

# %% [markdown]
# ### Buscando em varios

# %%
   

driver = webdriver.Firefox()
driver.get(df['urls'][1])


try:
    find_titulo = driver.find_element_by_xpath(titulo)
    print(find_titulo.text)
except:
    print('Não encontramos titulo.')

try:
    find_quantidade_vendida = driver.find_element_by_xpath(quantidade_vendida)
    print(find_quantidade_vendida.text)
except:
    print('Não encontramos quantidade vendida')

try:
    find_preco = driver.find_element_by_xpath("//meta[@itemprop='price']")
    print('R$', find_preco.get_attribute("content"))
except:
    print('Não encontramos preço')
try:
    find_marca = driver.find_element_by_xpath(marca)
    print(find_marca.text)
except:
    print('Não encontramos marca')
try:
    find_linha = driver.find_element_by_xpath(linha)
    print(find_linha.text)
except:
    print('Não encontramos linha')    
try:
    find_modelo = driver.find_element_by_xpath(modelo)
    print(find_modelo.text)
except:
    print('Não encontramos modelo')    
try:
    find_preca = driver.find_element_by_xpath(numero_preca)
    print(find_preca.text)
except:
    print('Não encontramos peça')    
try:
    find_quantidade_velas = driver.find_element_by_xpath(quantidade_velas)
    print(find_quantidade_velas.text)
except:
    print('Não encontramos quantidade de velas')

# %% [markdown]
# ### Codigo rodando com apenas 1 df

# %%
lista_vazia = []
for a in range(1,53):
    lista_vazia.append(a)

# %%
guarda_info = []

# %%
def rodar (rodar_df):
    driver = webdriver.Firefox()
    driver.get(df['urls'][rodar_df])

    print(rodar_df)
    
    try:
        busca_titulo = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[1]/div/div[2]/h1').text
        print(f'Titulo: {busca_titulo}')
    except:
        print('Não encontrei')
        busca_titulo = ('Não encontrei titulo')
    try:
        busca_qntd_vendida = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[1]/div/div[1]/span').text        
        if busca_qntd_vendida == 'Novo':
            busca_qntd_vendida = 0
            print('Quantidade vendida: 0')
    except:
        print('Não encontrei qntd vendida')
        busca_qntd_vendida = ('Não encontrei qntd vendida')
        
    try:
        busca_preco1 = driver.find_element_by_xpath("//meta[@itemprop='price']")
        busca_preco = ('R$', busca_preco1.get_attribute("content"))
        print(f'Busca preço: {busca_preco}')
    except:
        print('Nao encontrei')
        busca_preco = ('Não encontrei preço')
    try:
        busca_marca = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[1]/td/span').text
        print(f'Busca marca: {busca_marca}')
    except:
        print('Nao encontrei')
        busca_marca = ('Não encontrei marca')
    try:
        busca_numero_peca = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[2]/td/span').text
        print(f'Numero peça: {busca_numero_peca}')
    except:
        print('Nao encontrei')
        busca_numero_peca = ('Não encontrei peça')
    try:
        busca_qntd_velas = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[3]/td/span').text
        print(f'Qntd de velas: {busca_qntd_velas}')
    except:
        print('Nao encontrei')
        busca_qntd_velas = ('Não encontrei quantidade velas')
        

    lista = [busca_titulo, busca_preco, busca_qntd_vendida, busca_marca, busca_numero_peca, busca_qntd_velas] 
    
    guarda_info.append(lista)
    
    
    driver.close()

# %%
for i in lista_vazia:
    rodar(i)
# Out:
# 1
# Titulo: Vela Ignicao Multi-e Audi A3 1.6 8v Gasolina 1999 2000
# Quantidade vendida: 0
# Busca preço: ('R$', '21.78')
# Busca marca: Magneti Marelli
# Numero peça: K5RBJYMM-10
# Qntd de velas: 1
# 2
# Titulo: Vela Ignicao Multi-e Polo 1.6 8v Gasolina 2002 2003
# Quantidade vendida: 0
# Busca preço: ('R$', '21.78')
# Busca marca: Magneti Marelli
# Numero peça: K5RBJYMM-10
# Qntd de velas: 1
# 3
# Titulo: Vela Ignicao Multi-e Polo 1.6 8v Gasolina 2005 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.78')
# Busca marca: Magneti Marelli
# Numero peça: K5RBJYMM-10
# Qntd de velas: 1
# 4
# Titulo: Vela Ignicao Multi-e Fox 1.0 8v Gasolina 2007
# Quantidade vendida: 0
# Busca preço: ('R$', '21.78')
# Busca marca: Magneti Marelli
# Numero peça: K5RBJYMM-10
# Qntd de velas: 1
# 5
# Titulo: Vela Ignicao V-form Colt 1.3 Gasolina 1996 1997 1998
# Quantidade vendida: 0
# Busca preço: ('R$', '21.59')
# Busca marca: Magneti Marelli
# Numero peça: K5RFMM-11
# Qntd de velas: 1
# 6
# Titulo: Vela Ignicao Resistiva Maxima Gasolina 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 7
# Titulo: Vela Ignicao Hyundai I30 2.0 16v 09/... Sp40 01 Und
# Quantidade vendida: 0
# Busca preço: ('R$', '21.99')
# Nao encontrei
# Nao encontrei
# Nao encontrei
# 8
# Titulo: Vela De Ignição Denso T20epr-u - Cód.2382
# Quantidade vendida: 0
# Busca preço: ('R$', '21.50')
# Nao encontrei
# Nao encontrei
# Nao encontrei
# 9
# Titulo: Vela Ignicao Resistiva I30 2.0 Gasolina 2009 2010 2011
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 10
# Titulo: Vela Ignicao Resistiva Elantra 2.0 16v Gasolina 2000 2001
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 11
# Titulo: Vela Ignicao Resistiva Rodeo 2.6 Gasolina 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 12
# Titulo: Vela Ignicao Resistiva Carens 2.0 16v Gasolina 2006 2007
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 13
# Titulo: Vela Ignicao Resistiva Cerato 2.0 16v Gasolina 2004 2005
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 14
# Titulo: Vela Ignicao Resistiva Cerato 2.0 16v Gasolina 2006 2007
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 15
# Titulo: Vela Ignicao Resistiva Tucson 2.0 Gasolina 2004 2005 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 16
# Titulo: Vela Ignicao Resistiva Carens 2 2.0 Gasolina 2004 2005 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 17
# Titulo: Vela Ignicao Resistiva Picanto 1.1 Gasolina 2003 2004 2005
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 18
# Titulo: Vela Ignicao Resistiva Sportage 2.5 Gasolina 2004 2005 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 19
# Titulo: Vela Ignicao Resistiva Cerato 1.6 16v Gasolina 2004 2005
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 20
# Titulo: Vela Ignicao Resistiva Pathfinder 3.3 V6 Gasolina 1997 1998
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 21
# Titulo: Vela Ignicao Resistiva Elantra 2.0 16v Gasolina 2002 2003
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 22
# Titulo: Vela Ignicao Resistiva Magentis 2.0 16v Gasolina 2009
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 23
# Titulo: Vela Ignicao Resistiva Galloper 3.0 V6 Gasolina 1998 1999
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 24
# Titulo: Vela Ignicao Resistiva Matrix 1.8 16v Gasolina 2001 2002
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 25
# Titulo: Vela Ignicao Resistiva Magentis 2.0 16v Gasolina 2005 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 26
# Titulo: Vela Ignicao Resistiva Sportage 2.0 16v Gasolina 2004 2005
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 27
# Titulo: Vela Ignicao Resistiva Picanto 1.1 12v Gasolina 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 28
# Titulo: Vela Ignicao Resistiva Carens 2 2.0 Gasolina 2007
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 29
# Titulo: Vela Ignicao Resistiva Picanto 1.1 Gasolina 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 30
# Titulo: Vela Ignicao Resistiva Galloper 3.0 V6 Gasolina 2000 2001
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 31
# Titulo: Vela Ignicao Resistiva Matrix 1.8 16v Gasolina 2003
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 32
# Titulo: Vela Ignicao Resistiva Cerato 1.6 16v Gasolina 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 33
# Titulo: Vela Ignicao Resistiva Magentis 2.0 16v Gasolina 2007 2008
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 34
# Titulo: Vela Ignicao Resistiva Sportage 2.0 16v Gasolina 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 35
# Titulo: Vela Ignicao Resistiva Pathfinder 3.3 V6 Gasolina 1999 2000
# Quantidade vendida: 0
# Busca preço: ('R$', '21.01')
# Busca marca: Magneti Marelli
# Numero peça: K5RTCMM-11
# Qntd de velas: 1
# 36
# Titulo: Vela Ignicao V-form Charade 1.3 Gasolina 1995
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 37
# Titulo: Vela Ignicao V-form Charade 1.5 Gasolina 1994 1995 1996 1997
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 38
# Titulo: Vela Ignicao V-form Feroza 1.6 Gasolina 1994 1995 1996 1997
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 39
# Titulo: Vela Ignicao V-form Picanto 1.0 Gasolina 2004 2005 2006
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 40
# Titulo: Vela Ignicao V-form Charade 1.6 Gasolina 1994 1995 1996 1997
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 41
# Titulo: Vela Ignicao V-form Carens 1.6 Gasolina 2002 2003 2004
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 42
# Titulo: Vela Ignicao V-form Colt 1.6 Gasolina 1992 1993 1994 1995
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 43
# Titulo: Vela Ignicao V-form Colt 1.6 Gasolina 1991 1992 1993 1994
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 44
# Titulo: Vela Ignicao V-form Galant 2.0 Gasolina 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 45
# Titulo: Vela Ignicao V-form Lancer 1.6 Gasolina 1993 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 46
# Titulo: Vela Ignicao V-form Colt 1.8 Gasolina 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 47
# Titulo: Vela Ignicao V-form Lancer 1.8 Gasolina 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 48
# Titulo: Vela Ignicao V-form Colt 1.8 Gasolina 1991 1992 1993 1994
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 49
# Titulo: Vela Ignicao V-form Galant 2.0 Gasolina 1993 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 50
# Titulo: Vela Ignicao V-form Lancer 1.8 Gasolina 1993 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 51
# Titulo: Vela Ignicao V-form Vivio 0.7 Gasolina 1993 1994 1995 1996
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1
# 52
# Titulo: Vela Ignicao V-form Jimny 1.3 Gasolina 2001 2002 2003
# Quantidade vendida: 0
# Busca preço: ('R$', '21.88')
# Busca marca: Magneti Marelli
# Numero peça: K6RF2MM-11
# Qntd de velas: 1

# %% [markdown]
# ### Salvar final

# %%
#como era apenas 1 df deixei para salvar no final.

# %%
df_salvar = pd.DataFrame(guarda_info)
df_salvar.to_csv('teste_busca.csv')

# %% [markdown]
# ### Tentando fazer rodar com varios df

# %%
lista_vazia = []
for a in range(1,53):
    lista_vazia.append(a)

# %%
guarda_info = []

# %%
def rodar (rodar_df):
    driver = webdriver.Firefox()
    
    for files in file:
        print(f'Vai começar processar o arquivo: {files}.')
        csv = pd.read_csv(r'C:\Users\kkaua\Data Science\Mercado Livre\mercado_livre_2\soluções\5_bases\bases\{}'.format(files))
        driver.get(df['urls'][rodar_df])

        print(rodar_df)
    
    
        try:
            busca_titulo = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[1]/div/div[1]/div/div[1]/div/div[2]/h1').text
            print(busca_titulo)
        except:
            print('Não encontrei')
            busca_titulo = ('Não encontrei titulo')
        try:
            busca_qntd_vendida = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[1]/div/div[2]/div[1]/div/div/div[3]/ul/li[1]/strong').text
        except:
            print('Não encontrei') 
            busca_qntd_vendida = ('Não encontrei quantidade vendida')
        try:
            busca_preco1 = driver.find_element_by_xpath("//meta[@itemprop='price']")
            busca_preco = ('R$', busca_preco1.get_attribute("content"))
            print(busca_preco)
        except:
            print('Nao encontrei')
            busca_preco = ('Não encontrei preço')
        try:
            busca_marca = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div/table/tbody/tr[1]').text
            print(busca_marca)
        except:
            print('Nao encontrei')
            busca_marca = ('Não encontrei marca')
        try:
            busca_linha = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[2]').text
            print(busca_linha)
        except:
            print('Nao encontrei')
            busca_linha = ('Não encontrei linha')
        try:
            busca_modelo = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[3]').text
            print(busca_modelo)
        except:
            print('Nao encontrei')
            busca_modelo = ('Não encontrei modelo')
        try:
            busca_numero_peca = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[4]').text
            print(busca_numero_peca)
        except:
            print('Nao encontrei')
            busca_numero_peca = ('Não encontrei peça')
        try:
            busca_qntd_velas = driver.find_element_by_xpath('/html/body/main/div/div[3]/div/div[2]/div[2]/div[2]/div/div[1]/table/tbody/tr[5]').text
            print(busca_qntd_velas)
        except:
            print('Nao encontrei')
            busca_qntd_velas = ('Não encontrei quantidade velas')


        lista = [busca_titulo, busca_preco, busca_qntd_vendida, busca_marca, busca_linha, busca_modelo, busca_numero_peca, busca_qntd_velas]   

        guarda_info.append(lista)


    driver.close()

# %%
for i in lista_vazia:
    rodar(i)

# %% [markdown]
# ### Aréa de testes

# %%
import pandas as pd
import glob

# %%
path = r'C:\Users\kkaua\Data Science\Mercado Livre\mercado_livre_2\identificar_colunas\5_bases\bases' # use your path
all_files = glob.glob(path + "/*.csv")
print(all_files)

# %%
for filename in all_files:
    print(f'vai começar o arquivo{filename}')
    df = pd.read_csv(filename, index_col=None, header=0)

# %%
def rodar(rodar_df):
    for filename in all_files:
        print(f'vai começar o arquivo{filename}')
        df = pd.read_csv(filename, index_col=None, header=0)
        df['urls'][rodar_df]
rodar(1)

# %%
def rodar(rodar_df):
    for filename in all_files:
        print(f'vai começar o arquivo{filename}')
        df = pd.read_csv(filename, index_col=None, header=0)
        print(df['urls'][rodar_df])
rodar(1)

# %%
#testando essa df

# %%
def rodar(rodar_df):
    for filename in all_files:
        print(f'vai começar o arquivo{filename}')
        df = pd.read_csv(filename, index_col=None, header=0)
    print(df['urls'][rodar_df])
rodar(1)
